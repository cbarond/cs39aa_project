# %% [markdown]
# # Project Part 3
#
# [![Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/cbarond/cs39aa_project/blob/main/project_part3.ipynb)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cbarond/cs39aa_project/blob/main/project_part3.ipynb)

# %%
import numpy as np
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification,  TrainingArguments, Trainer
from datasets import load_dataset, load_metric
import wandb

wandb.init(project="cs39aa-final")
wandb.config = {
  "learning_rate": 0.001,
  "epochs": 45,
  "batch_size": 128
}

dataset = load_dataset("emotion")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Device: {device}')
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb version 0.13.5 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.21
# Run data is saved locally in <code>/kaggle/working/wandb/run-20221203_225110-2mdl02t9</code>
# Syncing run <strong><a href="https://wandb.ai/cbaron/cs39aa-final/runs/2mdl02t9" target="_blank">dashing-disco-10</a></strong> to <a href="https://wandb.ai/cbaron/cs39aa-final" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Downloading builder script:   0%|          | 0.00/1.66k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# Downloading and preparing dataset emotion/default (download: 1.97 MiB, generated: 2.07 MiB, post-processed: Unknown size, total: 4.05 MiB) to /root/.cache/huggingface/datasets/emotion/default/0.0.0/348f63ca8e27b3713b6c04d723efe6d824a56fb3d1449794716c0f0296072705...
# Downloading data:   0%|          | 0.00/1.66M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/204k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/207k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/16000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Dataset emotion downloaded and prepared to /root/.cache/huggingface/datasets/emotion/default/0.0.0/348f63ca8e27b3713b6c04d723efe6d824a56fb3d1449794716c0f0296072705. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Device: cuda

# %% [markdown]
# I used bert-base-uncased and froze all layers except the final.

# %%
MODEL_NAME = "bert-base-cased"
MAX_LENGTH=50

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=6, max_length=MAX_LENGTH, output_attentions=False, output_hidden_states=False).to(device)

for param in model.bert.parameters():
    param.requires_grad = False

print(f'Model set: {MODEL_NAME}')
# Out:
# Downloading:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/426k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/416M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForSequenceClassification: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model set: bert-base-cased

# %%
def tokenize_function(examples):
    return tokenizer(examples['text'], padding="max_length", truncation=True, max_length=MAX_LENGTH)

ds_train = dataset['train'].map(tokenize_function, batched=True)
ds_test = dataset['test'].map(tokenize_function, batched=True)
ds_valid = dataset['validation'].map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/16 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]

# %%
ds_train = ds_train.shuffle(seed=42)
ds_valid = ds_valid.shuffle(seed=42)
ds_test = ds_test.shuffle(seed=42)

# %% [markdown]
# I loaded the training arguments with the config set earlier.

# %%
import os
os.environ["WANDB_DISABLED"] = "false"

metric = load_metric("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

training_args = TrainingArguments(#num_train_epochs=100,
                                  num_train_epochs=wandb.config['epochs'],
                                  do_train=True,
                                  report_to='wandb',
                                  output_dir='/kaggle/working',
                                  learning_rate=wandb.config['learning_rate'],
                                  #learning_rate=.001,
                                  per_device_train_batch_size=wandb.config['batch_size'],
                                  #per_device_train_batch_size=128,
                                  per_device_eval_batch_size=16,
                                  save_strategy='epoch',
                                  evaluation_strategy='epoch'
                                  #eval_steps=500,
                                  )

trainer = Trainer(model = model, 
                  args = training_args,
                  train_dataset = ds_train, 
                  eval_dataset = ds_valid,
                  compute_metrics = compute_metrics,
)

torch.set_grad_enabled(True)
print('Training...')
trainer.train()
print('Evaluating...')
trainer.evaluate()
# Out:
# Downloading builder script:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# The following columns in the training set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 16000
#   Num Epochs = 45
#   Instantaneous batch size per device = 128
#   Total train batch size (w. parallel, distributed & accumulation) = 128
#   Gradient Accumulation steps = 1
#   Total optimization steps = 5625
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# Training...
#     <div>
#
#       <progress value='5625' max='5625' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5625/5625 22:38, Epoch 45/45]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.559422</td>
#       <td>0.341000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.486302</td>
#       <td>0.442500</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.469420</td>
#       <td>0.434500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.514400</td>
#       <td>1.456451</td>
#       <td>0.448500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.514400</td>
#       <td>1.422071</td>
#       <td>0.478000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.514400</td>
#       <td>1.443534</td>
#       <td>0.443500</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.514400</td>
#       <td>1.410064</td>
#       <td>0.482000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.448100</td>
#       <td>1.402235</td>
#       <td>0.489000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.448100</td>
#       <td>1.428491</td>
#       <td>0.449000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.448100</td>
#       <td>1.388676</td>
#       <td>0.480500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.448100</td>
#       <td>1.407068</td>
#       <td>0.502000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.421900</td>
#       <td>1.366192</td>
#       <td>0.496000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.421900</td>
#       <td>1.373249</td>
#       <td>0.498000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.421900</td>
#       <td>1.370607</td>
#       <td>0.521000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.421900</td>
#       <td>1.357342</td>
#       <td>0.497000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.404400</td>
#       <td>1.376673</td>
#       <td>0.495500</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.404400</td>
#       <td>1.361975</td>
#       <td>0.497500</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.404400</td>
#       <td>1.355244</td>
#       <td>0.492000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.404400</td>
#       <td>1.344263</td>
#       <td>0.502000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.393300</td>
#       <td>1.354255</td>
#       <td>0.492500</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.393300</td>
#       <td>1.353794</td>
#       <td>0.520000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.393300</td>
#       <td>1.336376</td>
#       <td>0.509500</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.393300</td>
#       <td>1.343485</td>
#       <td>0.513000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.386400</td>
#       <td>1.344632</td>
#       <td>0.514000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.386400</td>
#       <td>1.355722</td>
#       <td>0.482500</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.386400</td>
#       <td>1.332516</td>
#       <td>0.514500</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.386400</td>
#       <td>1.348328</td>
#       <td>0.492000</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.381600</td>
#       <td>1.336031</td>
#       <td>0.497500</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.381600</td>
#       <td>1.325332</td>
#       <td>0.522500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.381600</td>
#       <td>1.326381</td>
#       <td>0.516500</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.381600</td>
#       <td>1.337872</td>
#       <td>0.499500</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.376000</td>
#       <td>1.326072</td>
#       <td>0.510000</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.376000</td>
#       <td>1.337385</td>
#       <td>0.499000</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.376000</td>
#       <td>1.322884</td>
#       <td>0.509000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.376000</td>
#       <td>1.322238</td>
#       <td>0.522500</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.374000</td>
#       <td>1.318067</td>
#       <td>0.512500</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.374000</td>
#       <td>1.318866</td>
#       <td>0.516500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.374000</td>
#       <td>1.322712</td>
#       <td>0.516500</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.374000</td>
#       <td>1.317138</td>
#       <td>0.512500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.371000</td>
#       <td>1.318074</td>
#       <td>0.514500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.371000</td>
#       <td>1.320343</td>
#       <td>0.519000</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.371000</td>
#       <td>1.321759</td>
#       <td>0.522000</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.371000</td>
#       <td>1.317240</td>
#       <td>0.515500</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.368200</td>
#       <td>1.318042</td>
#       <td>0.514000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.368200</td>
#       <td>1.317843</td>
#       <td>0.515500</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-125
# Configuration saved in /kaggle/working/checkpoint-125/config.json
# Model weights saved in /kaggle/working/checkpoint-125/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-250
# Configuration saved in /kaggle/working/checkpoint-250/config.json
# Model weights saved in /kaggle/working/checkpoint-250/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-375
# Configuration saved in /kaggle/working/checkpoint-375/config.json
# Model weights saved in /kaggle/working/checkpoint-375/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-500
# Configuration saved in /kaggle/working/checkpoint-500/config.json
# Model weights saved in /kaggle/working/checkpoint-500/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-625
# Configuration saved in /kaggle/working/checkpoint-625/config.json
# Model weights saved in /kaggle/working/checkpoint-625/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-750
# Configuration saved in /kaggle/working/checkpoint-750/config.json
# Model weights saved in /kaggle/working/checkpoint-750/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-875
# Configuration saved in /kaggle/working/checkpoint-875/config.json
# Model weights saved in /kaggle/working/checkpoint-875/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-1000
# Configuration saved in /kaggle/working/checkpoint-1000/config.json
# Model weights saved in /kaggle/working/checkpoint-1000/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-1125
# Configuration saved in /kaggle/working/checkpoint-1125/config.json
# Model weights saved in /kaggle/working/checkpoint-1125/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-1250
# Configuration saved in /kaggle/working/checkpoint-1250/config.json
# Model weights saved in /kaggle/working/checkpoint-1250/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-1375
# Configuration saved in /kaggle/working/checkpoint-1375/config.json
# Model weights saved in /kaggle/working/checkpoint-1375/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-1500
# Configuration saved in /kaggle/working/checkpoint-1500/config.json
# Model weights saved in /kaggle/working/checkpoint-1500/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-1625
# Configuration saved in /kaggle/working/checkpoint-1625/config.json
# Model weights saved in /kaggle/working/checkpoint-1625/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-1750
# Configuration saved in /kaggle/working/checkpoint-1750/config.json
# Model weights saved in /kaggle/working/checkpoint-1750/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-1875
# Configuration saved in /kaggle/working/checkpoint-1875/config.json
# Model weights saved in /kaggle/working/checkpoint-1875/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-2000
# Configuration saved in /kaggle/working/checkpoint-2000/config.json
# Model weights saved in /kaggle/working/checkpoint-2000/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-2125
# Configuration saved in /kaggle/working/checkpoint-2125/config.json
# Model weights saved in /kaggle/working/checkpoint-2125/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-2250
# Configuration saved in /kaggle/working/checkpoint-2250/config.json
# Model weights saved in /kaggle/working/checkpoint-2250/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-2375
# Configuration saved in /kaggle/working/checkpoint-2375/config.json
# Model weights saved in /kaggle/working/checkpoint-2375/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-2500
# Configuration saved in /kaggle/working/checkpoint-2500/config.json
# Model weights saved in /kaggle/working/checkpoint-2500/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-2625
# Configuration saved in /kaggle/working/checkpoint-2625/config.json
# Model weights saved in /kaggle/working/checkpoint-2625/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-2750
# Configuration saved in /kaggle/working/checkpoint-2750/config.json
# Model weights saved in /kaggle/working/checkpoint-2750/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-2875
# Configuration saved in /kaggle/working/checkpoint-2875/config.json
# Model weights saved in /kaggle/working/checkpoint-2875/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-3000
# Configuration saved in /kaggle/working/checkpoint-3000/config.json
# Model weights saved in /kaggle/working/checkpoint-3000/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-3125
# Configuration saved in /kaggle/working/checkpoint-3125/config.json
# Model weights saved in /kaggle/working/checkpoint-3125/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-3250
# Configuration saved in /kaggle/working/checkpoint-3250/config.json
# Model weights saved in /kaggle/working/checkpoint-3250/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-3375
# Configuration saved in /kaggle/working/checkpoint-3375/config.json
# Model weights saved in /kaggle/working/checkpoint-3375/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-3500
# Configuration saved in /kaggle/working/checkpoint-3500/config.json
# Model weights saved in /kaggle/working/checkpoint-3500/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-3625
# Configuration saved in /kaggle/working/checkpoint-3625/config.json
# Model weights saved in /kaggle/working/checkpoint-3625/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-3750
# Configuration saved in /kaggle/working/checkpoint-3750/config.json
# Model weights saved in /kaggle/working/checkpoint-3750/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-3875
# Configuration saved in /kaggle/working/checkpoint-3875/config.json
# Model weights saved in /kaggle/working/checkpoint-3875/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-4000
# Configuration saved in /kaggle/working/checkpoint-4000/config.json
# Model weights saved in /kaggle/working/checkpoint-4000/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-4125
# Configuration saved in /kaggle/working/checkpoint-4125/config.json
# Model weights saved in /kaggle/working/checkpoint-4125/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-4250
# Configuration saved in /kaggle/working/checkpoint-4250/config.json
# Model weights saved in /kaggle/working/checkpoint-4250/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-4375
# Configuration saved in /kaggle/working/checkpoint-4375/config.json
# Model weights saved in /kaggle/working/checkpoint-4375/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-4500
# Configuration saved in /kaggle/working/checkpoint-4500/config.json
# Model weights saved in /kaggle/working/checkpoint-4500/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-4625
# Configuration saved in /kaggle/working/checkpoint-4625/config.json
# Model weights saved in /kaggle/working/checkpoint-4625/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-4750
# Configuration saved in /kaggle/working/checkpoint-4750/config.json
# Model weights saved in /kaggle/working/checkpoint-4750/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-4875
# Configuration saved in /kaggle/working/checkpoint-4875/config.json
# Model weights saved in /kaggle/working/checkpoint-4875/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-5000
# Configuration saved in /kaggle/working/checkpoint-5000/config.json
# Model weights saved in /kaggle/working/checkpoint-5000/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-5125
# Configuration saved in /kaggle/working/checkpoint-5125/config.json
# Model weights saved in /kaggle/working/checkpoint-5125/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-5250
# Configuration saved in /kaggle/working/checkpoint-5250/config.json
# Model weights saved in /kaggle/working/checkpoint-5250/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-5375
# Configuration saved in /kaggle/working/checkpoint-5375/config.json
# Model weights saved in /kaggle/working/checkpoint-5375/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-5500
# Configuration saved in /kaggle/working/checkpoint-5500/config.json
# Model weights saved in /kaggle/working/checkpoint-5500/pytorch_model.bin
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Saving model checkpoint to /kaggle/working/checkpoint-5625
# Configuration saved in /kaggle/working/checkpoint-5625/config.json
# Model weights saved in /kaggle/working/checkpoint-5625/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: text. If text are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 2000
#   Batch size = 16
# Evaluating...
#     <div>
#
#       <progress value='125' max='125' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [125/125 00:03]
#     </div>
# {'eval_loss': 1.317842721939087,
#  'eval_accuracy': 0.5155,
#  'eval_runtime': 4.0148,
#  'eval_samples_per_second': 498.153,
#  'eval_steps_per_second': 31.135,
#  'epoch': 45.0}

# %% [markdown]
# # Results
#
# Due to hardware limitations and other issues, I was unable to run this for longer. With this in mind, I got the following results:
#
# Accuracy: 0.5155
# Loss: 1.318
#
# More data can be found [here](https://wandb.ai/cbaron/cs39aa-final/runs/2mdl02t9?workspace=user-cbaron)
#
# <img src="images/W&B_Chart_Accuracy.png" alt="Accuracy" width="800"/>
# <img src="images/W&B_Chart_Loss.png" alt="Loss" width="800"/>
